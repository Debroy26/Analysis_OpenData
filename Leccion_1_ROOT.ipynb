# %% [markdown]
# # INICIO AL ANÁLISIS DE DATOS ABIERTOS LHCb
#
# En esta lección aprenderemos a interactuar con datos de física de partículas. El objetivo es entender la estructura de un archivo `.root` y visualizar las variables de momento.
#
# ---
#
# ### 🎯 Objetivos de aprendizaje
# 1.  **Cargar** la librería de ROOT en Python.
# 2.  **Abrir** el archivo de datos `PhaseSpaceSimulation.root`.
# 3.  **Inspeccionar** las ramas (variables) disponibles.
#
# <div style="background-color: #fff3cd; padding: 10px; border-left: 5px solid #ffecb5;">
#     <strong>⚠️ Importante:</strong> Asegúrate de que el archivo .root esté en la carpeta del proyecto. Git lo ignorará al subir (por el .gitignore), pero tú lo necesitas localmente para que el código corra.
# </div>

# %%
import ROOT

# 1. Cargamos los datos de forma elegante
df = ROOT.RDataFrame("PhaseSpaceTree", "PhaseSpaceSimulation.root")

# 2. Listamos las columnas para que el alumno las vea
print("Columnas detectadas en el archivo:")
for col in df.GetColumnNames():
    print(f" - {col}")
# Out:
# Columnas detectadas en el archivo:
#  - B_FlightDistance
#  - B_VertexChi2
#  - H1_Charge
#  - H1_IPChi2
#  - H1_PX
#  - H1_PY
#  - H1_PZ
#  - H1_ProbK
#  - H1_ProbPi
#  - H1_isMuon
#  - H2_Charge
#  - H2_IPChi2
#  - H2_PX
#  - H2_PY
#  - H2_PZ
#  - H2_ProbK
#  - H2_ProbPi
#  - H2_isMuon
#  - H3_Charge
#  - H3_IPChi2
#  - H3_PX
#  - H3_PY
#  - H3_PZ
#  - H3_ProbK
#  - H3_ProbPi
#  - H3_isMuon

# %%
import ROOT
